# %%
import numpy as np
z=np.linspace(5,6.5,1000)
Hb=4862
Ha=6564

for i in z:
    print(Hb*(1+i))
    print(Ha*(1+i))
    print(" ")
    if Hb*(i+1)>39000 and  Hb*(i+1)<49000 and Ha*(i+1)>39000 and  Ha*(i+1)<49000:
        print(Hb*(1+i))
        print(Ha*(1+i))
# Out:
# 29172.0
# 39384.0
#
# 29179.300300300303
# 39393.85585585586
#
# 29186.6006006006
# 39403.71171171171
#
# 29193.900900900902
# 39413.56756756757
#
# 29201.2012012012
# 39423.423423423425
#
# 29208.5015015015
# 39433.27927927928
#
# 29215.801801801805
# 39443.13513513514
#
# 29223.1021021021
# 39452.99099099099
#
# 29230.402402402404
# 39462.84684684685
#
# 29237.7027027027
# 39472.7027027027
#
# 29245.003003003003
# 39482.55855855856
#
# 29252.303303303306
# 39492.414414414416
#
# 29259.603603603602
# 39502.270270270266
#
# 29266.903903903905
# 39512.126126126124
#
# 29274.2042042042
# 39521.98198198198
#
# 29281.504504504504
# 39531.83783783784
#
# 29288.804804804808
# 39541.6936936937
#
# 29296.105105105104
# 39551.54954954955
#
# 29303.405405405407
# 39561.40540540541
#
# 29310.705705705703
# 39571.26126126126
#
# 29318.006006006006
# 39581.117117117115
#
# 29325.30630630631
# 39590.97297297297
#
# 29332.606606606605
# 39600.828828828824
#
# 29339.90690690691
# 39610.68468468469
# ...

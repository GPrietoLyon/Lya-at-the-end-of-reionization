# %%
import numpy as np
import glob as glob
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.io import ascii
import scipy.integrate
from scipy.optimize import curve_fit

# %%
stack_file=fits.open("../../A-Catalogs/large_files/fresco-only-n-v2_21531.stack.fits")

# %%
np.shape(stack_file[1].data)
# Out:
# (64, 630)

# %%
plt.rcParams["figure.figsize"] = (30,30.)
sns.set_theme(style="ticks",font_scale=2.2)

plt.imshow(stack_file[1].data,vmin=0,vmax=0.02)
plt.axhline(y=31)
